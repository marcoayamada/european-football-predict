# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Pandas options

# Formatando e deixando os números sem casas decimais para notação cientifica.
pd.options.display.float_format = '{:.0f}'.format

# numero maximo de linhas
pd.set_option('display.max_rows', 500)

# %%
# Seaborn and matplotlib options

plt.figure(figsize=(15,5));
sns.set(rc={'figure.figsize':(15,5), 'xtick.direction':'in'});

# Função que seta algumas propriedades dos graficos mpl.
def cfg_plot(title='', xlabel='', ylabel='', rotation=0):
    plt.xticks(rotation=rotation)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
df = pd.read_json('base-dados-clube-da-aposta.json')

# %%
ordens_coluna = ['home_name', 'away_name', 'home_score', 'away_score', 'final_result',
       'time', 'home_pos', 'away_pos', 'round', 'home_last5all_home',
       'home_last5all_home_win', 'home_last5all_home_draw',
       'home_last5all_home_lose', 'away_last5all_away',
       'away_last5all_away_win', 'away_last5all_away_draw',
       'away_last5all_away_lose', 'last5all_home_away_dif', 'fifa_home_ova',
       'fifa_home_att', 'fifa_home_mid', 'fifa_home_def', 'fifa_away_ova',
       'fifa_away_att', 'fifa_away_mid', 'fifa_away_def', 'elo_home_score',
       'elo_away_score', 'tfm_value_home', 'tfm_value_away']

# %%
df = df[ordens_coluna]

# %%
df = df.sort_index()

# %%
df.head(10)
# Out:
#         home_name  away_name  home_score  away_score final_result        time  \
# 0        FC Porto   Nacional           3           1            H  1546895700
# 1        Tenerife      Elche           2           1            H  1546632000
# 2           Niort      Brest           1           1            D  1545420600
# 3       Liverpool    Man Utd           3           1            H  1544976000
# 4     Southampton    Arsenal           3           2            H  1544967000
# 5        Brighton    Chelsea           1           2            A  1544967000
# 6          Fulham   West Ham           0           2            A  1544895000
# 7    Huddersfield  Newcastle           0           1            A  1544886000
# 8  Crystal Palace  Leicester           1           0            H  1544886000
# 9       Tottenham    Burnley           1           0            H  1544886000
#
#    home_pos  away_pos  round  home_last5all_home       ...        \
# 0         1        11     16                   9       ...
# 1        18        15     20                   2       ...
# 2         7         2     19                   1       ...
# 3         2         6     17                  11       ...
# 4        19         5     17                  -3       ...
# 5        13         4     17                   3       ...
# 6        20        11     17                  -6       ...
# 7        18        15     17                  -3       ...
# 8        16         9     17                   0       ...
# 9         3        17     17                   5       ...
#
#    fifa_home_mid  fifa_home_def  fifa_away_ova  fifa_away_att  fifa_away_mid  \
# 0             81             80             70             70             70
# 1             71             69             67             69             67
# 2             65             65             68             68             68
# 3             83             81             83             84             82
# 4             77             77             82             85             83
# 5             75             76             83             84             84
# 6             76             73             78             79             77
# 7             74             75             76             76             76
# 8             77             76             78             82             77
# 9             83             83             77             76             77
#
#    fifa_away_def  elo_home_score  elo_away_score  tfm_value_home  \
# 0             69            1814            1393       277980000
# 1             67            1513            1476        10900000
# 2             69            1385            1496         6700000
# 3             79            1931            1841       913000000
# 4             80            1606            1856       266100000
# 5             83            1637            1859       177000000
# 6             77            1574            1690       250500000
# 7             76            1546            1625       120600000
# 8             78            1640            1686       219250000
# 9             77            1907            1617       837500000
#
#    tfm_value_away
# 0         9450000
# 1         9600000
# 2        15850000
# 3       835000000
# 4       574000000
# 5       892250000
# 6       287500000
# 7       174000000
# 8       344500000
# 9       181750000
#
# [10 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5163 entries, 0 to 5162
# Data columns (total 30 columns):
# home_name                  5163 non-null object
# away_name                  5163 non-null object
# home_score                 5163 non-null int64
# away_score                 5163 non-null int64
# final_result               5163 non-null object
# time                       5163 non-null int64
# home_pos                   5163 non-null int64
# away_pos                   5163 non-null int64
# round                      5163 non-null int64
# home_last5all_home         5163 non-null int64
# home_last5all_home_win     5163 non-null int64
# home_last5all_home_draw    5163 non-null int64
# home_last5all_home_lose    5163 non-null int64
# away_last5all_away         5163 non-null int64
# away_last5all_away_win     5163 non-null int64
# away_last5all_away_draw    5163 non-null int64
# away_last5all_away_lose    5163 non-null int64
# last5all_home_away_dif     5163 non-null int64
# fifa_home_ova              5163 non-null int64
# fifa_home_att              5163 non-null int64
# fifa_home_mid              5163 non-null int64
# fifa_home_def              5163 non-null int64
# fifa_away_ova              5163 non-null int64
# fifa_away_att              5163 non-null int64
# fifa_away_mid              5163 non-null int64
# fifa_away_def              5163 non-null int64
# elo_home_score             5163 non-null float64
# elo_away_score             5163 non-null float64
# tfm_value_home             5163 non-null float64
# tfm_value_away             5163 non-null float64
# dtypes: float64(4), int64(23), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# Não há distinção entre ligas dos países. Isso pode ser um fator que pode influenciar no resultado.

# %%
df.home_name.value_counts().head()
# Out:
# Man City       35
# Chelsea        35
# Southampton    34
# Swansea        34
# West Brom      34
# Name: home_name, dtype: int64

# %% [markdown]
# Existem times duplicados no dataset. O conjunto de dados retrata os resultados de várias rodadas de vários campeonatos.

# %% [markdown]
# ## Home x Away scores
#
# Quem ganhou na maioria das vezes? Mandante ou visitante?

# %%
df.final_result.value_counts().plot(kind='bar', color='salmon')
cfg_plot('Quem ganhou mais: mandante ou visitante?', 'Lado da vitória', 'Quantidade')

# %% [markdown]
# Como era de se esperar, mandantes ganham mais. Mas os visitantes também tem uma parcela de vitórias. Vamos investigar!

# %% [markdown]
# ## fifa_ova e tfm_value
#
# O ranking na FIFA e o valor de mercado do time influenciam nas vitórias dos visitantes? Vamos ver:

# %%
only_away = df[df.final_result == 'A'][['home_name', 'away_name','fifa_home_ova', 'fifa_away_ova', 'tfm_value_home', 'tfm_value_away']]
only_away.head()
# Out:
#        home_name        away_name  fifa_home_ova  fifa_away_ova  \
# 5       Brighton          Chelsea             76             83
# 6         Fulham         West Ham             76             78
# 7   Huddersfield        Newcastle             75             76
# 11       Levante        Barcelona             76             86
# 16    Valladolid  Atletico Madrid             73             84
#
#     tfm_value_home  tfm_value_away
# 5        177000000       892250000
# 6        250500000       287500000
# 7        120600000       174000000
# 11        86000000      1230000000
# 16        41700000       898000000

# %%
ova_diff = only_away[['fifa_home_ova', 'fifa_away_ova']].apply(lambda x: x[1]-x[0],axis=1)
ova_diff
# Out:
# 5        7
# 6        2
# 7        1
# 11      10
# 16      11
# 20       7
# 22       2
# 24       8
# 28       4
# 30       8
# 32      11
# 34      -1
# 39       5
# 41       2
# 43       8
# 45       1
# 58       3
# 63       0
# 71       4
# 72       1
# 80       3
# 83       3
# 85      -1
# 94       8
# 99       9
# 100      4
# 102     -1
# 104      4
# 105     11
# 106      1
# 115     -4
# 116      3
# 118      7
# 122      3
# 123      3
# 125      1
# 129      1
# 132     10
# 136      7
# 139      0
# 140      4
# 146     10
# 147     -1
# 151      8
# 155      3
# 157      1
# 160      7
# 161      1
# 166      8
# 169      0
# 170      7
# 172      7
# 175      2
# 184     -2
# 192     -9
# 193      4
# 195      0
# 197      6
# 204      3
# 206      5
# 210     -7
# 211      6
# 214      7
# 218     -5
# 221     -2
# 224     -1
# 229      5
# 230      5
# 236     -1
# 238      5
# 243     -3
# 246      0
# 248      1
# 249      7
# 253      2
# 254      2
# 256      1
# 259      5
# 261      7
# 265      9
# 269      0
# 270     -7
# 276      1
# 279     -1
# 281     -4
# 283     10
# 288     -2
# 291      7
# 293      7
# 295      1
# 296      0
# 301      8
# 307      3
# 308      7
# 309      0
# 312      5
# 317      0
# 322      0
# 324      1
# 325      2
# 331      1
# 334      3
# 335     -3
# 338      3
# 341      2
# 342      0
# 349      0
# 350      0
# 351      0
# 353     -2
# 363      1
# 366      3
# 373      3
# 383     -1
# 384      2
# 389     -1
# 394     -1
# 404     -2
# 410      0
# 415      0
# 416      2
# 427      1
# 428      0
# 432     -3
# 435     -5
# 440     -2
# 444      0
# 451     -3
# 452      2
# 458     -1
# 463      4
# 472     -1
# 473     -1
# 475      5
# 476      2
# 479      0
# 481      4
# 482     -2
# 485      1
# 486      0
# 488      0
# 491      0
# 492      3
# 497      2
# 498      3
# 499      2
# 500     -1
# 502     -5
# 504      1
# 508      3
# 510      0
# 514      2
# 515     -1
# 518     -2
# 522      1
# 524     -1
# 527      2
# 528      4
# 531      3
# 537      0
# 539      5
# 543      0
# 544     -1
# 546     -3
# 550      1
# 560      1
# 564      1
# 567      4
# 570      5
# 575      1
# 577     -4
# 583      4
# 587      1
# 589      4
# 596      3
# 599      1
# 601     -2
# 602      0
# 610     -2
# 612      4
# 616      3
# 621      0
# 623      2
# 629      2
# 630     -2
# 631      0
# 637     -3
# 643     -1
# 644     -1
# 646      6
# 648     -1
# 649      2
# 651      3
# 652      0
# 654     -2
# 656      3
# 664     -2
# 668     -6
# 672      5
# 673      1
# 675      3
# 678     -2
# 680      3
# 682      3
# 686      0
# 687      5
# 691     -5
# 693      2
# 698     -4
# 700     -1
# 702     -1
# 716      0
# 735      0
# 737      3
# 738     -1
# 739      4
# 741      3
# 743     -4
# 745     -4
# 746     -1
# 749      2
# 751      5
# 752     -1
# 755      2
# 759      2
# 760     -1
# 764     -3
# 766      3
# 769      2
# 775      2
# 778     -2
# 782      4
# 784     -2
# 786      0
# 790      2
# 792      1
# 797     -1
# 800     -2
# 801      1
# 803      1
# 806      1
# 809      0
# 814     -2
# 815      0
# 816      2
# 820     -2
# 824      4
# 832      2
# 836      0
# 847      2
#         ..
# 4389    11
# 4391    -5
# 4396     3
# 4398     1
# 4400    10
# 4403     4
# 4404    -6
# 4405    -1
# 4406    -2
# 4412     3
# 4413     4
# 4414     4
# 4418     4
# 4421     7
# 4424     6
# 4425    -4
# 4427     3
# 4429     0
# 4431     5
# 4434     4
# 4436     4
# 4438     0
# 4439    -5
# 4440     8
# 4446     5
# 4447    -2
# 4449     6
# 4451     4
# 4455    11
# 4457     4
# 4463     1
# 4466     0
# 4467    -6
# 4469     1
# 4473     0
# 4476    -1
# 4477     7
# 4483     2
# 4485     2
# 4486     1
# 4489     4
# 4492     9
# 4495    10
# 4496     6
# 4499     7
# 4504    -3
# 4507    -2
# 4508    10
# 4510     9
# 4513     6
# 4514    10
# 4517     6
# 4520    10
# 4522     0
# 4526     2
# 4533     4
# 4536    -3
# 4539     2
# 4543    -2
# 4548     2
# 4550     3
# 4554    -2
# 4556     9
# 4559    -6
# 4560    -5
# 4568    13
# 4569    -5
# 4574     2
# 4575     3
# 4576     6
# 4583    -4
# 4586     2
# 4588     0
# 4591     3
# 4595    10
# 4596     9
# 4597     8
# 4601     9
# 4602     4
# 4606    -1
# 4607     0
# 4609     4
# 4613     5
# 4614     2
# 4616     0
# 4617     2
# 4618     3
# 4621     4
# 4624    -6
# 4626     0
# 4628     4
# 4629     6
# 4632    10
# 4637     5
# 4643    -2
# 4645     5
# 4647     6
# 4650    -2
# 4656     2
# 4657     6
# 4658     0
# 4661     7
# 4665     4
# 4666     2
# 4669     9
# 4677    -1
# 4682     3
# 4685    -4
# 4688     7
# 4689     9
# 4692     0
# 4693    -2
# 4694     9
# 4698     0
# 4709     4
# 4710     0
# 4713     9
# 4717     4
# 4718     3
# 4721     3
# 4729     9
# 4730     5
# 4732     3
# 4741    -4
# 4742     0
# 4743     3
# 4745     6
# 4746     3
# 4748     0
# 4757     2
# 4758     1
# 4762     9
# 4763     5
# 4770    -7
# 4771     0
# 4773     0
# 4778    11
# 4780     0
# 4786     3
# 4789     7
# 4792     3
# 4793    -2
# 4795     3
# 4797    -3
# 4801    11
# 4812     7
# 4813     9
# 4814     8
# 4816     3
# 4817     4
# 4821     2
# 4825     4
# 4835     7
# 4836    -5
# 4840    -3
# 4842     9
# 4845     2
# 4848     5
# 4849     1
# 4856    11
# 4862    10
# 4865    -5
# 4867     6
# 4868     2
# 4869     7
# 4875     4
# 4877     9
# 4881     5
# 4885     2
# 4891     5
# 4900     6
# 4901     3
# 4914     0
# 4918     9
# 4930    10
# 4933    11
# 4934     2
# 4937     1
# 4940     9
# 4943     1
# 4952     5
# 4959     3
# 4962     8
# 4965    11
# 4966    -1
# 4967     3
# 4968    -6
# 4970    11
# 4974     9
# 4975     8
# 4976    -3
# 4978     3
# 4979     2
# 4980     3
# 4982     3
# 4989     5
# 4992     1
# 4994     2
# 4995     9
# 4996     7
# 4999     6
# 5000     7
# 5008     7
# 5013     8
# 5015     8
# 5016     1
# 5018    -1
# 5026     1
# 5032    -1
# 5035    -1
# 5039     7
# 5040     8
# 5043     2
# 5045     5
# 5053     6
# 5055     7
# 5061     2
# 5063     9
# 5064    -1
# 5069     8
# 5072     0
# 5074    -3
# 5075     6
# 5076    -1
# 5081     1
# 5083     6
# 5086     2
# 5088    -4
# 5089    -4
# 5090     8
# 5094     1
# 5095     5
# 5098     3
# 5102     4
# 5104     6
# 5106    -4
# 5109    -4
# 5119    -9
# 5121     1
# 5126     1
# 5127     0
# 5137     6
# 5141     6
# 5143     1
# 5145     5
# 5147     9
# 5148    -9
# 5149    -3
# 5157     2
# 5162     7
# Length: 1500, dtype: int64

# %%
ova_diff.value_counts().count()
# Out:
# 27

# %%
# total de registros
total_reg = ova_diff.value_counts()

ova_diff.hist(bins=total_reg.count())
plt.xticks(ova_diff.value_counts().index)
cfg_plot("Quantidade de vencedores visitantes e a diferença entre o overall do away e do home", 
         "Diferença entre o FIFA Overall", 
         "Quantidade")

# %% [markdown]
# Diferenças positivas indicam que o time visitante tem o ranking mais alto.
# Diferenças negativas indicam que o time da casa tem o ranking mais alto.
#
# Os dados retratam praticamente uma curva normal padrão. As diferenças positivas parecem seguir uma tendência mais suave até o final, enquanto as diferenças negativas parecem não ser tão suaves assim.

# %%
print('Desvio padrão: {0}'.format(ova_diff.std()))
print('Média: {0}'.format(ova_diff.mean()))
# Out:
# Desvio padrão: 4.063045300465072
# Média: 2.001333333333333

# %% [markdown]
# Verificando a média e o desvio padrão dos dados, é possível notar que 95% dos dados encontram-se entre -6 e 10. Isso é suficiente para dizer que a maioria dos times com o Overall maior ganham mais jogos fora de casa.
#
# Então times com Overall baixo que ganham de times melhores, são considerados zebras? Difícil saber sem analisar outras características separadamente como Overall apenas da defesa ou gols pró em todo campeonato.
#
# Times com menor investimento geralmente possuem Overall mais baixo e quando esses times enfretam clubes maiores geralmente se fecham na defesa e esperam AQUELA bola do jogo inteiro mesmo jogando em casa, mas isso claro que não é regra. É necessário analisar outras características para afirmar algo com mais precisão.

# %%
vm_diff = (only_away[['tfm_value_home', 'tfm_value_away']].apply(lambda x: x[1]-x[0],axis=1))/1000000 # diferença entre milhões
vm_diff
# Out:
# 5       715
# 6        37
# 7        53
# 11     1144
# 16      856
# 20      403
# 22       86
# 24      625
# 28       65
# 30      260
# 32      257
# 34       -3
# 39      106
# 41        4
# 43      149
# 45        5
# 58       76
# 63       -1
# 71       43
# 72        3
# 80       11
# 83        2
# 85        2
# 94      158
# 99      147
# 100     120
# 102      -3
# 104     167
# 105     176
# 106       5
# 115     -20
# 116       2
# 118     176
# 122     121
# 123       9
# 125      14
# 129      -4
# 132     189
# 136      33
# 139       8
# 140      16
# 146     161
# 147      -6
# 151     161
# 155     139
# 157       3
# 160     155
# 161       0
# 166      90
# 169      18
# 170     -11
# 172      46
# 175     100
# 184     -73
# 192    -119
# 193      45
# 195      76
# 197      76
# 204     113
# 206      42
# 210     -46
# 211      -9
# 214     -16
# 218     -50
# 221     -10
# 224     -46
# 229       0
# 230     -20
# 236      -6
# 238       9
# 243       4
# 246     -23
# 248     -67
# 249      63
# 253      17
# 254      44
# 256      24
# 259      33
# 261      44
# 265      87
# 269       1
# 270     -70
# 276      11
# 279      -6
# 281     -22
# 283      89
# 288     -17
# 291      62
# 293      50
# 295     -52
# 296       0
# 301      73
# 307      49
# 308      45
# 309      -0
# 312      45
# 317     -58
# 322       1
# 324      -3
# 325       1
# 331      11
# 334       6
# 335      -7
# 338       1
# 341       9
# 342      -0
# 349       3
# 350       2
# 351      -6
# 353      -5
# 363       2
# 366       8
# 373      10
# 383      -7
# 384      -3
# 389       6
# 394      -4
# 404      -6
# 410      -1
# 415       1
# 416      -2
# 427       2
# 428       2
# 432      -5
# 435      -9
# 440      -0
# 444       0
# 451      -4
# 452       5
# 458      -3
# 463      11
# 472       0
# 473      -4
# 475      14
# 476       3
# 479       3
# 481      11
# 482      -5
# 485       3
# 486       0
# 488       0
# 491      -4
# 492       6
# 497      10
# 498       8
# 499       9
# 500      -2
# 502     -14
# 504       4
# 508      10
# 510      -3
# 514       4
# 515      -0
# 518      -6
# 522       5
# 524      -5
# 527       6
# 528      19
# 531      24
# 537       2
# 539      28
# 543       1
# 544      -3
# 546      -9
# 550       1
# 560       3
# 564       2
# 567      20
# 570      31
# 575      13
# 577      -7
# 583      17
# 587      13
# 589       3
# 596       9
# 599      -7
# 601      -1
# 602      -0
# 610      -5
# 612       8
# 616      -2
# 621      -3
# 623       1
# 629       6
# 630      -9
# 631       6
# 637     -18
# 643       3
# 644      -3
# 646      11
# 648      -3
# 649      13
# 651      14
# 652       2
# 654      -5
# 656       1
# 664       5
# 668     -17
# 672       5
# 673      15
# 675       7
# 678      -8
# 680       9
# 682      16
# 686       5
# 687       2
# 691     -10
# 693       9
# 698      -6
# 700       1
# 702      -5
# 716      11
# 735       2
# 737      10
# 738      -4
# 739      14
# 741      -2
# 743     -11
# 745      -4
# 746      -9
# 749       8
# 751      10
# 752      -1
# 755       5
# 759       4
# 760      -3
# 764      -3
# 766      10
# 769       6
# 775       1
# 778     -10
# 782      10
# 784      -7
# 786      -2
# 790      -0
# 792      -3
# 797      -3
# 800      -6
# 801       2
# 803       6
# 806       7
# 809      -0
# 814      -6
# 815       3
# 816      10
# 820      -5
# 824       9
# 832       9
# 836       5
# 847      10
#        ...
# 4389    382
# 4391   -183
# 4396     75
# 4398     -3
# 4400    471
# 4403    223
# 4404   -223
# 4405     40
# 4406    -72
# 4412     38
# 4413     49
# 4414     98
# 4418    186
# 4421    277
# 4424    238
# 4425    -50
# 4427     19
# 4429    -14
# 4431     60
# 4434    240
# 4436    190
# 4438     16
# 4439    -42
# 4440    250
# 4446    200
# 4447    -24
# 4449    266
# 4451    133
# 4455    465
# 4457    197
# 4463     25
# 4466     27
# 4467   -340
# 4469     -9
# 4473    -14
# 4476    -28
# 4477    133
# 4483     37
# 4485    167
# 4486     54
# 4489     97
# 4492    441
# 4495    250
# 4496    278
# 4499     83
# 4504    -39
# 4507    -51
# 4508    456
# 4510    323
# 4513    197
# 4514    328
# 4517    241
# 4520    388
# 4522    156
# 4526     70
# 4533    201
# 4536   -227
# 4539     81
# 4543    -13
# 4548      3
# 4550     63
# 4554   -132
# 4556    268
# 4559   -185
# 4560    -67
# 4568    413
# 4569   -135
# 4574    159
# 4575     80
# 4576    240
# 4583   -238
# 4586     20
# 4588     30
# 4591     71
# 4595    365
# 4596    147
# 4597    285
# 4601    257
# 4602     47
# 4606    -35
# 4607     -3
# 4609    100
# 4613    262
# 4614     46
# 4616     36
# 4617    -28
# 4618    123
# 4621     30
# 4624   -234
# 4626     17
# 4628    251
# 4629    126
# 4632    393
# 4637    180
# 4643    -71
# 4645     39
# 4647    258
# 4650    -57
# 4656     -2
# 4657    133
# 4658    113
# 4661    590
# 4665     81
# 4666    119
# 4669    300
# 4677    -42
# 4682     37
# 4685   -194
# 4688    298
# 4689    653
# 4692    -55
# 4693    -63
# 4694    669
# 4698     32
# 4709    108
# 4710      3
# 4713    592
# 4717     78
# 4718     22
# 4721     75
# 4729    580
# 4730    191
# 4732     87
# 4741    -84
# 4742     27
# 4743     69
# 4745    112
# 4746    381
# 4748      6
# 4757     74
# 4758     33
# 4762    608
# 4763     82
# 4770   -124
# 4771     33
# 4773      4
# 4778    611
# 4780     32
# 4786     29
# 4789    215
# 4792     76
# 4793     -9
# 4795     35
# 4797   -107
# 4801    490
# 4812    229
# 4813    546
# 4814    229
# 4816    100
# 4817     89
# 4821      7
# 4825    145
# 4835    387
# 4836    -74
# 4840    -22
# 4842    176
# 4845     41
# 4848    161
# 4849     -3
# 4856    432
# 4862    425
# 4865   -154
# 4867    158
# 4868     59
# 4869    168
# 4875     24
# 4877    417
# 4881     33
# 4885     62
# 4891    160
# 4900    150
# 4901     56
# 4914      6
# 4918    151
# 4930    192
# 4933    182
# 4934     24
# 4937      6
# 4940    144
# 4943      1
# 4952     41
# 4959    114
# 4962    152
# 4965    176
# 4966      0
# 4967     36
# 4968    -19
# 4970    153
# 4974    166
# 4975    148
# 4976     -1
# 4978     16
# 4979      1
# 4980      6
# 4982     13
# 4989    136
# 4992     -0
# 4994     17
# 4995    157
# 4996    141
# 4999     35
# 5000    153
# 5008     38
# 5013    608
# 5015    410
# 5016     31
# 5018     -4
# 5026     90
# 5032    -16
# 5035      6
# 5039    638
# 5040    583
# 5043     13
# 5045    255
# 5053    615
# 5055    628
# 5061    127
# 5063    584
# 5064      9
# 5069    576
# 5072     18
# 5074     -6
# 5075    279
# 5076     40
# 5081     52
# 5083    293
# 5086     40
# 5088    -67
# 5089   -246
# 5090    298
# 5094     67
# 5095    263
# 5098    173
# 5102    292
# 5104    260
# 5106   -182
# 5109    -56
# 5119   -669
# 5121     34
# 5126     15
# 5127    -24
# 5137    239
# 5141    188
# 5143     -4
# 5145     21
# 5147    181
# 5148   -165
# 5149     -6
# 5157     48
# 5162    146
# Length: 1500, dtype: float64

# %%
plt.hist(vm_diff, bins=100)
cfg_plot("Quantidade de vencedores visitantes e a diferença entre o valor de mercado do away e do home", 
         "Diferença entre valor de mercado (em milhões de Euros)", 
         "Quantidade")

# %% [markdown]
# Apenas por esse gráfico é possível notar que a vitória do visitante acontece em grande parte das vezes quando o time de fora vale mais (a diferença pode chegar a 750 milhões de Euros!).
#
# Um fato interessante está no outlier que aparenta uma diferença pequena de valores. Limitando apenas para o outlier:

# %%
# limitando o range
plt.hist(vm_diff, bins=80, range=(-40,100))
cfg_plot("Quantidade de vencedores visitantes e a diferença entre o valor de mercado do away e do home", 
         "Diferença entre valor de mercado (em milhões de Euros)", 
         "Quantidade")

# %% [markdown]
# O outlier positivo é devido à concentração das diferenças até 20 milhões de Euros. É nessa faixa que acontecem grande parte das vitórias fora de casa.

# %%
df_prov = df[['home_name', 'away_name']]
df_prov['diff_values'] = df.apply(lambda x: x['tfm_value_home']-x['tfm_value_away'], axis=1)/1000000
df_prov[(df_prov['diff_values'] <= 20) & (df_prov['diff_values'] >= 15)].sort_values(by='home_name')

#Diferenças positivas indicam times da casa com valor maior. Diferenças negativas indicam times de fora com valor maior.
# Out:
# C:\Users\Mark\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                 home_name            away_name  diff_values
# 1572         ADO Den Haag        De Graafschap           16
# 2778                   AZ           FC Utrecht           16
# 2676                 Ajax            Feyenoord           17
# 1429               Angers                Nimes           16
# 4894               Angers                Nancy           18
# 2913          Antalyaspor           Alanyaspor           16
# 3208          Aston Villa        Middlesbrough           19
# 1537             Augsburg          SC Freiburg           15
# 2238              Auxerre           AS Beziers           16
# 3063           Birmingham            Sheff Utd           17
# 1765            Blackburn            Rotherham           18
# 93                  Braga            Guimaraes           20
# 1754            Brentford            Sheff Utd           18
# 3085            Brentford            Sheff Utd           16
# 2157              Brescia              Cosenza           19
# 2136              Brescia              Livorno           18
# 1089              Burnley          Bournemouth           18
# 282           CSKA Moscow     Lokomotiv Moscow           17
# 2139              Crotone              Cosenza           19
# 576               Crotone                Carpi           15
# 1901  Deportivo La Coruna                Elche           17
# 1404                Dijon               Angers           17
# 3618        Dinamo Moscow            Krasnodar           18
# 5062                Eibar           Las Palmas           16
# 2473  Eintracht Frankfurt        VfB Stuttgart           20
# 278      FC Akhmat Grozny                 Ural           17
# 288      FC Akhmat Grozny    Anzhi Makhachkala           17
# 493         FC Ingolstadt         MSV Duisburg           16
# 4981             FC Porto              Benfica           15
# 4927             FC Porto             Sporting           16
# 214                FC Ufa            Krasnodar           16
# 2001               FC Ufa    Anzhi Makhachkala           16
# 2830           FC Utrecht            Excelsior           19
# 1571           FC Utrecht             Heracles           16
# 2813           FC Utrecht         ADO Den Haag           18
# 2765           FC Utrecht            Willem II           18
# 1651           FC Utrecht           PEC Zwolle           18
# 2688           FC Utrecht             Heracles           16
# 2824           FC Utrecht           PEC Zwolle           15
# 586             Frosinone               Foggia           15
# 3230               Fulham              Reading           15
# 3409              Granada              Almeria           15
# 3414              Granada               Huesca           16
# 3449              Granada                 Lugo           16
# 3459              Granada              Cordoba           17
# 5158            Guimaraes      Vitoria Setubal           17
# 4968            Guimaraes              Tondela           19
# 4973            Guimaraes             Feirense           19
# 154             Guimaraes           Moreirense           20
# 126             Guimaraes             Boavista           16
# 5150            Guimaraes           Moreirense           20
# 4804             Guingamp           Strasbourg           17
# 4839             Guingamp                Dijon           16
# 4873             Guingamp                Nancy           15
# 566           Hannover 96    Arminia Bielefeld           19
# 529           Hannover 96   Fortuna Dusseldorf           19
# 2767           Heerenveen             Heracles           19
# 2640           Heerenveen            Willem II           19
# 2610           Heerenveen         ADO Den Haag           15
# 2708           Heerenveen           PEC Zwolle           16
# 2580        Hertha Berlin  Eintracht Frankfurt           17
# 2492        Hertha Berlin        Werder Bremen           19
# 2354        Hertha Berlin          SC Freiburg           19
# 3094                 Hull              Norwich           16
# 2897            Kasimpasa     Akhisar Belediye           16
# 1937           Las Palmas        Reus Deportiu           16
# 1905           Las Palmas             Alcorcon           17
# 60             Las Palmas             Tenerife           18
# 1866           Las Palmas               Oviedo           17
# 3103                Leeds            Brentford           16
# 1752                Leeds              Reading           16
# 5032            Leicester             West Ham           16
# 1379                Lille           St Etienne           16
# 4853                Lille             Guingamp           18
# 854               Lorient         Ajaccio GFCA           20
# 845               Lorient        Clermont Foot           17
# 799               Lorient        US Orleans 45           15
# 787               Lorient             Paris FC           16
# 868               Lorient              Sochaux           16
# 728                  Metz         Ajaccio GFCA           15
# 1815        Middlesbrough              Swansea           17
# 4772               Nantes             Guingamp           18
# 4726               Nantes               Angers           15
# 4784               Nantes                 Metz           18
# 1406                 Nice               Rennes           16
# 3253              Norwich               Fulham           16
# 3212              Norwich           Birmingham           18
# 3418              Osasuna             Alcorcon           16
# 668               Palermo           Cittadella           17
# 653               Palermo          Salernitana           17
# 637               Palermo               Foggia           18
# 78                Palermo              Livorno           20
# 2158              Palermo              Venezia           15
# 1262                Parma               Empoli           15
# 2581           RB Leipzig              Cologne           17
# 1735              Reading            Sheff Utd           15
# 3237              Reading                Wigan           20
# 3210              Reading         Bristol City           17
# 3258              Reading            Blackburn           19
# 3292              Reading            Brentford           15
# 965                 Reims        US Orleans 45           16
# 987                 Reims           AC Ajaccio           17
# 1344               Rennes               Nantes           16
# 318                Rostov     FC Akhmat Grozny           15
# 222                Rostov            Krasnodar           16
# 231           Rubin Kazan     Lokomotiv Moscow           16
# 4633            Sampdoria              Bologna           17
# 1202             Sassuolo              Udinese           17
# 1207                 Spal               Empoli           16
# 4736           St Etienne               Nantes           19
# 3215           Sunderland                Leeds           17
# 3110           Sunderland            Brentford           19
# 1759              Swansea              Norwich           20
# 3927              Swansea            Newcastle           17
# 1777              Swansea              Reading           17
# 4708             Toulouse               Nantes           17
# 2922          Trabzonspor          Antalyaspor           19
# 2895          Trabzonspor              Goztepe           20
# 714                Verona                Carpi           15
# 2321        VfB Stuttgart        Werder Bremen           16
# 2749              Vitesse                  VVV           16
# 1614              Vitesse             Heracles           18
# 2695              Vitesse            Willem II           16
# 42                Vitesse                  VVV           19
# 3832            West Brom            Newcastle           19

# %% [markdown]
# Olhando rapidamente a lista gerada (entre 15 e 20 maiores diferenças) os times que se enquadram nesse range estão com os tamanhos bem próximos. Por exemplo, Aston Villa e Middlesbrough são times considerados fracos da Premier League. Por outro lado, os 3 maiores de Portugal também estão nessa listagem com os valores bem próximos.

# %% [markdown]
# ## Elo score
#
# Mais informções: [Como calcular Elo para seleções](https://en.wikipedia.org/wiki/FIFA_World_Rankings), [De onde o Elo veio](https://en.wikipedia.org/wiki/Elo_rating_system)
#
# O poder de previsão desse score tende a ser alto. Então provavelmente ele será usado no modelo final. Vamos explorá-lo um pouco:

# %%
df_elo = df[['elo_home_score', 'elo_away_score', 'final_result']]

# %%
df_elo['elo_diff'] = df_elo.apply(lambda x: x[0]-x[1],axis=1)

# Valores positivos: Home maior
# Valores negativos: Away maior
# Out:
# C:\Users\Mark\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# adicionando notação para facilitar a contagem de resultados positivos e negativos.
df_elo['pos_neg'] = df_elo.apply(lambda x: 'P' if x['elo_diff']>=0 else 'N' ,axis=1)
# Out:
# C:\Users\Mark\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_elo.head()
# Out:
#    elo_home_score  elo_away_score final_result  elo_diff pos_neg
# 0            1814            1393            H       421       P
# 1            1513            1476            H        38       P
# 2            1385            1496            D      -111       N
# 3            1931            1841            H        90       P
# 4            1606            1856            H      -250       N

# %% [markdown]
# ### Analisando os resultados de acordo com o score Elo
#
# #### 1) Vitória Home & Score+-
#
# Mandantes geralmente ganham os jogos. Times mais fracos podem se beneficiar disso mesmo tendo um time mais fraco. Um score `positivo` significa que o time da casa tem o score mais alto que o time de fora.

# %%
df_elo[df_elo.final_result=='H'].pos_neg.value_counts().plot(kind='bar', color='salmon')
cfg_plot("Vitória dos mandantes", "Elo score Positivo ou negativo", "Quantidade")

# %% [markdown]
# Mandantes e elo score positivo realmente ganham a maioria dos jogos - quase o dobro das vezes.

# %% [markdown]
# #### 2) Vitória Away & Score+-

# %%
df_elo[df_elo.final_result=='A'].pos_neg.value_counts().plot(kind='bar', color='salmon')
cfg_plot("Vitória dos visitantes", "Elo score Positivo ou negativo", "Quantidade")

# %% [markdown]
# Como era de se esperar, os times visitantes que ganham fora de casa são melhores que os mandantes. Isso acontece mais que o dobro das vezes. Mas esses times são muito piores?

# %%
df_elo[df_elo.final_result=='A'].describe()
# Out:
#        elo_home_score  elo_away_score  elo_diff
# count            1500            1500      1500
# mean             1540            1615       -75
# std               126             168       139
# min              1259            1286      -519
# 25%              1439            1483      -160
# 50%              1532            1590       -60
# 75%              1630            1722        17
# max              1979            2045       362

# %% [markdown]
# Não. Os dados estão bem equilibrados. Talvez com um pouco de viés para as diferenças negativas.
#
# Enfim, esse score parece ser bastante importante para a determinação dos resultados. Um fator que talvez não seja considerado, seja o valor do time. Pode ser que o valor do time juntamente com score Elo forme uma dupla robusta para a criação do modelo.

# %% [markdown]
# #### 3) Empate & Score+-

# %%
df_elo[df_elo.final_result=='D'].pos_neg.value_counts().plot(kind='bar', color='salmon')
cfg_plot("Empate", "Elo score Positivo ou negativo", "Quantidade")

# %% [markdown]
# Um empate não tem local para acontecer. Quase na mesma proporção os scores são positivos e negativos. Será que os times são de scores semelhantes ou pode variar?

# %%
df_elo[df_elo.final_result=='D'].describe()
# Out:
#        elo_home_score  elo_away_score  elo_diff
# count            1357            1357      1357
# mean             1554            1562        -9
# std               133             139       119
# min              1260            1248      -471
# 25%              1455            1455       -71
# 50%              1537            1549        -7
# 75%              1638            1653        58
# max              2046            2044       426

# %% [markdown]
# Sim! O desvio padrão é bem mais alto que a média. Isso mostra que os empates ocorrem com uma variedade maior de scores Elo, o que na prática costuma acontecer com alguma frequência. Quando times pequenos empatam fora de casa contra times grandes é comum dizer que foi uma vitória para esses times, já que não existe um padrão que idetifique um empate com precisão já que os dados estão distribuídos mais uniformemente.x
